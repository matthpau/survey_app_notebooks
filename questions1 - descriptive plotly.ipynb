# %%
import warnings

warnings.simplefilter(action='ignore', category=FutureWarning)
import pandas as pd

#!pip install plotly
import plotly.express as px
plotly_standard_height = 500

# %%
pd.set_option("display.max_columns", None)
pd.set_option("io.excel.xls.writer", "xlwt")
df = pd.read_pickle('~/Downloads/responses_latest.pkl')
df = df[(df['survey_short_id'] == 15) & (df['has_valid_response'] == True)]

cleanup_fields = ['scale_score', 'analysis_group', 'choice']
df[cleanup_fields] = df[cleanup_fields].fillna(0).astype(int)

# A bit more cleanup
# Not doing audio for the moment
df = df[df.response_type != 'AU']

#Cols to drop
df = df.drop(['added', 'updated', 'question_number', 'text', 'transcription_status', 'filename', 'transcription_text',
              'language_code', 'language_code_short', 'language_confidence', 'transcription_confidence', 'survey',
              'active', 'redis_job_id', 'analysis_group', 'sentiment_result', 'has_dependents',
              'has_valid_response', 'survey_short_id'], axis=1)
# Out:
# As the xlwt package is no longer maintained, the xlwt engine will be removed in a future version of pandas. This is the only engine in pandas that supports writing in the xls format. Install openpyxl and write to an xlsx file instead.

# %%
## Reorganise the responses to have respondent_id as index, not response

reshaping = (('CH','choice_text'),('SC','scale_score'))
df_new = pd.DataFrame()
new_dfs = []
for s in reshaping:
    df_work = df.loc[df['response_type']==s[0]]
    df_work = df_work.pivot(index='respondent_id',columns=('question_sort_order', 'question_text'), values=[s[1]])
    
    new_dfs.append(df_work)

df_new = pd.concat(new_dfs, axis=1)
df_new = df_new.droplevel(level=0, axis=1) 


#Get schema for questions
schema_df = df_new.columns.to_frame(index=False).set_index('question_sort_order')
schema_df.sort_index(inplace=True)

df_new = df_new.droplevel(level=1, axis=1)
schema_df
# Out:
#                                                          question_text
# question_sort_order
# 10                   Zum Start, ein paar demografische Fragen.Bist du:
# 20                                                         Dein Alter?
# 30                                                 Dein Familienstand?
# 40                                         Deine berufliche Situation?
# 44                   Nun geht es um das Thema Covid Impfung.Wie ist...
# 50                   Ab hier geht's um Deine Motivationen. Ich geni...
# 60                   Ich lege großen Wert darauf, dass andere mich ...
# 70                        Ich fühle mich sehr wohl auf Familienfesten.
# 80                   Ich genieße es, mich in komplexe Sachverhalte ...
# 90                   Ich fühle mich wohl damit, wenn ich Entscheidu...
# 100                  Ich finde es wichtig, mich um Notleidende zu k...
# 110                  Es ist mir sehr wichtig, sparsam mit meinen Vo...
# 120                  Ich genieße es, wenn meine Wohnung aufgeräumt ...
# 130                  Meine Freundschaften und Bekanntschaften berei...
# 140                  Wenn mich jemand beleidigt, muss ich es ihm he...
# 150                                Ich komme allein gut klar im Leben.
# 160                  Ich umgehe Situationen, die andere für gefährl...
# 170                  Ich achte auf Sitten und Gebräuche, auf die Re...
# 180                  Meine Stellung in der Gesellschaft ist mir seh...
# 190                  Ich fühle mich wohl, wenn ich regelmäßig körpe...
# 200                  Ich fühle mich unwohl, wenn ich Dinge mache, d...
# 210                  Ich achte auf Möglichkeiten, meine Familie unt...
# 220                              Es gefällt mir, Dinge zu untersuchen.
# 230                    Ich fühle mich wohl in der Rolle des Anführers.
# 240                  Ich möchte einen Beitrag leisten, damit unsere...
# 250                    Ich bemühe mich, mein Geld und Gut zu erhalten.
# 260                  Wenn ich Durcheinander sehe, möchte ich sofort...
# 270                                 Ich lerne gerne neue Leute kennen.
# 280                  Ich lasse es mir nicht gefallen, wenn mich jem...
# 290                  Ich komme am besten klar im Leben, wenn ich mi...
# 300                               Ich lege großen Wert auf Sicherheit.
# 310                  Ich bin stolz auf meine moralischen Überzeugun...
# 320                  Ich suche nach Situationen, in denen ich mein ...
# 330                      Ich habe ein ausgeprägtes Bewegungsbedürfnis.
# 340                  Ich vermeide es, einen schlechten Eindruck auf...
# 350                  Ich denke häufig darüber nach, ob es den Mitgl...
# 360                                           Ich liebe es, zu denken.
# 370                  Es gefällt mir, wenn ich die Verantwortung für...
# 380                  Ich finde es furchtbar, Not und Benachteiligun...
# 390                    Andere würden mich als preisbewusst bezeichnen.
# 400                  Ich liebe es, Dinge zu ordnen und zu strukturi...
# 410                             Ich genieße Gespräche und Plaudereien.
# 420                  Ich finde es wichtig, anderen deutlich zu zeig...
# 430                  Es wäre schrecklich für mich, von anderen abhä...
# 440                  Ich fühle mich sehr unwohl, wenn ich eine Situ...
# 450                  Es fällt mir schwer, von Moralvorstellungen ab...
# 460                  Ich freue mich über die Stellung in der Gesell...

# %%
df_new[10].value_counts()
# Out:
# Weiblich    101
# Männlich     67
# Divers        6
# Name: 10, dtype: int64

# %%
df_new[20].value_counts()
# Out:
# 56 - 65 J     45
# 46 - 55 J     44
# 31 - 45 J     39
# 20-30 J       27
# über 65 J      8
# unter 20 J     2
# Name: 20, dtype: int64

# %%
df_new[30].value_counts()
# Out:
# Paar                  59
# Paar mit Kindern      59
# Single                38
# Single mit Kindern    11
# Name: 30, dtype: int64

# %%
df_new[40].value_counts()
# Out:
# Angestellt             63
# Selbstständig          47
# Öffentlicher Dienst    25
# Studierend             24
# In Ausbildung           6
# Name: 40, dtype: int64

# %%
res0 = df_new[44].value_counts()
res0
# Out:
# Ich bin schon länger geimpft                            123
# Ich bin nicht geimpft                                    20
# Ich habe mich vor kurzem impfen lassen                   17
# Ich bin genesen und geimpft (oder lasse mich impfen)      6
# Ich bin genesen und lasse mich nicht impfen               1
# Name: 44, dtype: int64

# %%
px.pie(values=res0.values, names=res0.index, title="Impfstatus", height = plotly_standard_height)

# %%
res1 = df_new.groupby([10])[44].value_counts(normalize=True)
res1 = res1.rename("count").reset_index()
res1
# Out:
#           10                                                 44     count
# 0     Divers                              Ich bin nicht geimpft  0.600000
# 1     Divers                       Ich bin schon länger geimpft  0.200000
# 2     Divers             Ich habe mich vor kurzem impfen lassen  0.200000
# 3   Männlich                       Ich bin schon länger geimpft  0.687500
# 4   Männlich             Ich habe mich vor kurzem impfen lassen  0.125000
# 5   Männlich                              Ich bin nicht geimpft  0.109375
# 6   Männlich  Ich bin genesen und geimpft (oder lasse mich i...  0.062500
# 7   Männlich        Ich bin genesen und lasse mich nicht impfen  0.015625
# 8   Weiblich                       Ich bin schon länger geimpft  0.795918
# 9   Weiblich                              Ich bin nicht geimpft  0.102041
# 10  Weiblich             Ich habe mich vor kurzem impfen lassen  0.081633
# 11  Weiblich  Ich bin genesen und geimpft (oder lasse mich i...  0.020408

# %%
px.bar(res1, y='count', x=10, color=44, title="Impfstatus / Geschlecht", height = plotly_standard_height)

# %%
res2= df_new.groupby([20])[44].value_counts(normalize=True)
res2 = res2.rename("count").reset_index()
res2[20] = pd.Categorical(res2[20], ["unter 20 J", "20-30 J", "31 - 45 J", "46 - 55 J", "56 -65 J", "über 65 J"])
res2 = res2.sort_values(20)
res2
# Out:
#             20                                                 44     count
# 16  unter 20 J                              Ich bin nicht geimpft  1.000000
# 0      20-30 J                       Ich bin schon länger geimpft  0.640000
# 1      20-30 J  Ich bin genesen und geimpft (oder lasse mich i...  0.120000
# 2      20-30 J                              Ich bin nicht geimpft  0.120000
# 3      20-30 J             Ich habe mich vor kurzem impfen lassen  0.080000
# 4      20-30 J        Ich bin genesen und lasse mich nicht impfen  0.040000
# 5    31 - 45 J                       Ich bin schon länger geimpft  0.615385
# 6    31 - 45 J                              Ich bin nicht geimpft  0.179487
# 7    31 - 45 J             Ich habe mich vor kurzem impfen lassen  0.179487
# 8    31 - 45 J  Ich bin genesen und geimpft (oder lasse mich i...  0.025641
# 9    46 - 55 J                       Ich bin schon länger geimpft  0.651163
# 10   46 - 55 J             Ich habe mich vor kurzem impfen lassen  0.162791
# 11   46 - 55 J                              Ich bin nicht geimpft  0.139535
# 12   46 - 55 J  Ich bin genesen und geimpft (oder lasse mich i...  0.046512
# 17   über 65 J                       Ich bin schon länger geimpft  1.000000
# 13         NaN                       Ich bin schon länger geimpft  0.911111
# 14         NaN                              Ich bin nicht geimpft  0.066667
# 15         NaN             Ich habe mich vor kurzem impfen lassen  0.022222

# %%
px.bar(res2, y='count', x=20, color=44, title="Impfstatus / Alter", height = plotly_standard_height)

# %%
res3= df_new.groupby([30])[44].value_counts(normalize=True)
res3 = res3.rename("count").reset_index()
res3
# Out:
#                     30                                                 44  \
# 0                 Paar                       Ich bin schon länger geimpft
# 1                 Paar                              Ich bin nicht geimpft
# 2                 Paar             Ich habe mich vor kurzem impfen lassen
# 3                 Paar  Ich bin genesen und geimpft (oder lasse mich i...
# 4                 Paar        Ich bin genesen und lasse mich nicht impfen
# 5     Paar mit Kindern                       Ich bin schon länger geimpft
# 6     Paar mit Kindern             Ich habe mich vor kurzem impfen lassen
# 7     Paar mit Kindern                              Ich bin nicht geimpft
# 8     Paar mit Kindern  Ich bin genesen und geimpft (oder lasse mich i...
# 9               Single                       Ich bin schon länger geimpft
# 10              Single  Ich bin genesen und geimpft (oder lasse mich i...
# 11              Single                              Ich bin nicht geimpft
# 12              Single             Ich habe mich vor kurzem impfen lassen
# 13  Single mit Kindern                       Ich bin schon länger geimpft
# 14  Single mit Kindern                              Ich bin nicht geimpft
# 15  Single mit Kindern             Ich habe mich vor kurzem impfen lassen
#
#        count
# 0   0.677966
# 1   0.186441
# 2   0.067797
# 3   0.050847
# 4   0.016949
# 5   0.741379
# 6   0.172414
# 7   0.068966
# 8   0.017241
# 9   0.861111
# 10  0.055556
# 11  0.055556
# 12  0.027778
# 13  0.636364
# 14  0.181818
# 15  0.181818

# %%
px.bar(res3, y='count', x=30, color=44, title="Impfstatus / Ehestand", height = plotly_standard_height)
